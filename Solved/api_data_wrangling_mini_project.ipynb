# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = ''

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import collections

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X/data.json?limit=10&api_key='+API_KEY
r = requests.get(url)
json = r.json()

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
print(json)
# Out:
# {'dataset_data': {'limit': 10, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'start_date': '2000-06-07', 'end_date': '2019-05-20', 'frequency': 'daily', 'data': [['2019-05-20', None, 89.85, 88.45, 88.55, None, 134676.0, 11985496.0, None, None, None], ['2019-05-17', None, 89.4, 88.55, 89.25, None, 117480.0, 10466561.0, None, None, None], ['2019-05-16', None, 89.3, 86.5, 89.2, None, 159067.0, 14088797.0, None, None, None], ['2019-05-15', None, 87.35, 85.1, 86.65, None, 145855.0, 12611298.0, None, None, None], ['2019-05-14', None, 87.1, 83.8, 86.0, None, 297843.0, 25587237.0, None, None, None], ['2019-05-13', None, 87.9, 85.85, 86.75, None, 122313.0, 10598375.0, None, None, None], ['2019-05-10', None, 87.65, 86.25, 86.9, None, 123258.0, 10704915.0, None, None, None], ['2019-05-09', None, 87.15, 85.25, 85.75, None, 156083.0, 13415858
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
#Question 1
#Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X/data.json?start_date=2017-01-01&end_date=2017-12-31&limit=10&api_key=' + API_KEY
r = requests.get(url)
Q1_json = r.json()
print(Q1_json)
# Out:
# {'dataset_data': {'limit': 10, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'frequency': 'daily', 'data': [['2017-12-29', 51.76, 51.94, 51.45, 51.76, None, 34640.0, 1792304.0, None, None, None], ['2017-12-28', 51.65, 51.82, 51.43, 51.6, None, 40660.0, 2099024.0, None, None, None], ['2017-12-27', 51.45, 51.89, 50.76, 51.82, None, 57452.0, 2957018.0, None, None, None], ['2017-12-22', 51.05, 51.5, 50.92, 51.32, None, 71165.0, 3641949.0, None, None, None], ['2017-12-21', 51.16, 51.52, 50.9, 51.4, None, 120649.0, 6179433.0, None, None, None], ['2017-12-20', 51.88, 52.04, 51.2, 51.27, None, 50587.0, 2610258.0, None, None, None], ['2017-12-19', 52.73, 52.73, 51.07, 51.66, None, 137313.0, 7102361.0, None, None, None], ['2017-12-18', 52.37, 52.75, 51.61, 52.62, None, 129733.0, 6770499
# ...

# %%
# Question2
#Convert the returned JSON object into a Python dictionary.
from collections import defaultdict

#Keys = Column names
Q2_list = Q1_json['dataset_data']['data']
Q2_dict_columns = defaultdict(list)
columns = Q1_json['dataset_data']['column_names']

for x in Q2_list:
    for i in range(len(columns)):
        Q2_dict_columns[columns[i]].append(x[i])

print(dict(Q2_dict_columns))
# Out:
# {'Date': ['2017-12-29', '2017-12-28', '2017-12-27', '2017-12-22', '2017-12-21', '2017-12-20', '2017-12-19', '2017-12-18', '2017-12-15', '2017-12-14'], 'Open': [51.76, 51.65, 51.45, 51.05, 51.16, 51.88, 52.73, 52.37, 52.7, 53.11], 'High': [51.94, 51.82, 51.89, 51.5, 51.52, 52.04, 52.73, 52.75, 52.7, 53.54], 'Low': [51.45, 51.43, 50.76, 50.92, 50.9, 51.2, 51.07, 51.61, 51.64, 52.15], 'Close': [51.76, 51.6, 51.82, 51.32, 51.4, 51.27, 51.66, 52.62, 52.01, 52.67], 'Change': [None, None, None, None, None, None, None, None, None, None], 'Traded Volume': [34640.0, 40660.0, 57452.0, 71165.0, 120649.0, 50587.0, 137313.0, 129733.0, 204080.0, 132981.0], 'Turnover': [1792304.0, 2099024.0, 2957018.0, 3641949.0, 6179433.0, 2610258.0, 7102361.0, 6770499.0, 10596319.0, 7016953.0], 'Last Price of the Day': [None, None, None, None, None, None, None, None, None, None], 'Daily Traded Units': [None, None, None, None, None, None, None, None, None, None], 'Daily Turnover': [None, None, None, None, None, Non
# ...

# %%
# Question 3 Calculate what the highest and lowest opening prices were for the stock in this period.
#Keys = Dates
Q2_dict_dates = {}
for x in Q2_list:
    Q2_dict_dates[x[0]] = x[1:]
print(Q2_dict_dates)
# Out:
# {'2017-12-29': [51.76, 51.94, 51.45, 51.76, None, 34640.0, 1792304.0, None, None, None], '2017-12-28': [51.65, 51.82, 51.43, 51.6, None, 40660.0, 2099024.0, None, None, None], '2017-12-27': [51.45, 51.89, 50.76, 51.82, None, 57452.0, 2957018.0, None, None, None], '2017-12-22': [51.05, 51.5, 50.92, 51.32, None, 71165.0, 3641949.0, None, None, None], '2017-12-21': [51.16, 51.52, 50.9, 51.4, None, 120649.0, 6179433.0, None, None, None], '2017-12-20': [51.88, 52.04, 51.2, 51.27, None, 50587.0, 2610258.0, None, None, None], '2017-12-19': [52.73, 52.73, 51.07, 51.66, None, 137313.0, 7102361.0, None, None, None], '2017-12-18': [52.37, 52.75, 51.61, 52.62, None, 129733.0, 6770499.0, None, None, None], '2017-12-15': [52.7, 52.7, 51.64, 52.01, None, 204080.0, 10596319.0, None, None, None], '2017-12-14': [53.11, 53.54, 52.15, 52.67, None, 132981.0, 7016953.0, None, None, None]}

# %%
#Instead of limits, look at the whole dataset for 2017.
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X/data.json?start_date=2017-01-01&end_date=2017-12-31&api_key=' + API_KEY
r = requests.get(url)
Q3_to_7_json = r.json()
Q3_to_7_list = Q3_to_7_json['dataset_data']['data']

#Print out the column names to remind ourselves what the columns are
print(json['dataset_data']['column_names'])
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover']

# %%
opening_prices = []
for row in Q3_to_7_list:
    if row[1] != None:
        opening_prices.append(row[1])
Q3_answer = ('Highest Opening Price: ' + str(max(opening_prices)) 
                     + '\n' + 'Lowest Opening Price: ' + str(min(opening_prices)))
print(Q3_answer)
# Out:
# Highest Opening Price: 53.11
# Lowest Opening Price: 34.0

# %%
# Question 4 What was the largest change in any one day (based on High and Low price)?
differences = []
for row in Q3_to_7_list:
    if row[2] != None and row[3] != None:
        differences.append(row[2] - row[3])
Q4_answer = ('Highest Change in 1 Day: ' + str(round(max(differences), 2)))
print(Q4_answer)
# Out:
# Highest Change in 1 Day: 2.81

# %%
# Question 5 What was the largest change between any two days (based on Closing Price)?
change = []
for i in range(len(Q3_to_7_list)):
    if i <= len(Q3_to_7_list) - 2:
        change.append(abs(Q3_to_7_list[i][4] - Q3_to_7_list[i+1][4]))
Q5_answer = ('Highest Change Between 2 Days: ' + str(round(max(change), 2)))
print(Q5_answer)
# Out:
# Highest Change Between 2 Days: 2.56

# %%
#Question 6 What was the average daily trading volume during this year?
trading_volume = []
for row in Q3_to_7_list:
    if row[6] != None:
        trading_volume.append(row[6])
Q6_answer = ('Mean volume traded: ' + str(sum(trading_volume)/len(trading_volume)))
print(Q6_answer)
# Out:
# Mean volume traded: 89124.33725490196

# %%
#Question 7 (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
def median(x):
    """Finding the median of a list of numbers"""
    x.sort()
    if len(x) // 2 == 0:
        value = (x[len(x) / 2] + x[len(x) / 2 + 1])/2
    else:
        value = x[round(len(x) / 2)]
    return value

Q7_answer = ('Median volume traded: ' + str(median(trading_volume)))
print(Q7_answer)
# Out:
# Median volume traded: 76600.0
